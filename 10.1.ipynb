# %% [markdown]
# # Unit 10  :-  Visualization & Streamlit UI

# %% [markdown]
# **1. MatPlotlib  Library  :**
# - plot
# - scatterplot
# - bar chart
# - histogram
# - area chart
# - pie chart

# %% [markdown]
# **1. plot  :**

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,6])
y=np.array([0,10])
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,6])
y=np.array([0,10])
plt.plot(x,y)
plt.show()

# %% [markdown]
# - marker parameter

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,6])
y=np.array([0,10])
plt.plot(x,y,'o') # o=circle marker
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,6])
y=np.array([0,10])
plt.plot(x,y,'v')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,6])
y=np.array([0,10])
plt.plot(x,y,'*')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,6])
y=np.array([0,10])
plt.plot(x,y,'s')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,6])
y=np.array([0,10])
plt.plot(x,y,'p')
plt.show()

# %% [markdown]
# ![NkAzy.png](attachment:NkAzy.png)

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,6])
y=np.array([0,10])
plt.plot(x,y,marker='o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,2,6,8])
y=np.array([3,7,2,5])
plt.plot(x,y,marker='o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,2,6,8])
y=np.array([3,7,7,9])
plt.plot(x,y,'*:g')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,2,6,8])
y=np.array([3,7,7,9])
plt.plot(x,y,'*-g')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,2,6,8])
y=np.array([3,7,7,9])
plt.plot(x,y,'*--g')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,2,6,8])
y=np.array([3,7,7,9])
plt.plot(x,y,'*-.r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,2,6,8])
y=np.array([3,7,2,9])
plt.plot(x,y,marker='*',ms=20)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,2,6,8])
y=np.array([3,7,7,9])
plt.plot(x,y,marker='*',ms=20,mec='g',mfc='r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([3,7,2,5])
plt.plot(y,marker='o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([3,7,2,5])
plt.plot(y,linestyle='dotted')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([3,7,2,5])
plt.plot(y,ls='dashed')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([3,7,2,5])
plt.plot(y,ls='dashed',linewidth=2) # or lw=2
plt.show()

# %% [markdown]
# **> UI Creation & Layout Fundamental :**
#
# ex1 - page setup & Text Elements

# %%
# %%writefile 1_hello.py
import streamlit as st
st.set_page_config(page_title='Hello Streamlit',page_icon='✨',layout='centered')
st.title('Welcome to Streamlit')
st.header('This is Header')
st.subheader('This is Subheader')
st.text('st.text() is used for simple fix width text')
st.write('st.write() more flexible and can display text,numbers,dataframes')
st.markdown('**st.markdown()** let you use markdown for **rich Text**')

code_example ="""
def add(a,b):
    return a+b
result=add(10,5)
print(result)"""
st.code(code_example,language='python')
# Out:
# Overwriting 1_hello.py

# %%
pwd
# Out:
# 'C:\\Users\\LJENG\\Untitled Folder'

# %% [markdown]
# **> Sidebar, columns ,Expands :**

# %%
# %%writefile 2_layout_basics.py
import streamlit as st
st.set_page_config(page_title='Faculty Profile',page_icon='✨',layout='centered')

st.title('Faculty Profile Demo')
st.markdown("this example shows how to use **sidebar,columns,expands**")

st.sidebar.header('profile settings')

faculty_name=st.sidebar.text_input("faculty name ","Tejas Thakkar")
department=st.sidebar.selectbox("Department ",['CE','IT','CSE','AIML'])
experience=st.sidebar.slider('Year of Experience ',0,40,10)

st.sidebar.markdown("---")
st.sidebar.write("You can put filters ,toggles etc in sidebar")

col1,col2=st.columns([1,2])
with col1:
    st.subheader('BAsic info')
    st.write(f"**Name :** {faculty_name}")
    st.write(f"**Department :** {department}")
    st.write(f"**Experience :** {experience}")
with col2:
    st.subheader("ABOUT")
    st.markdown('USe this area to show detailed information about the faculty members')
    
with st.expander('Show Courses handled'):
    st.write('python-1')
    st.write('python-2')
    st.write('DE')
with st.expander("Show Publication"):
    st.write('1. research paper A(201)')
    st.write('2. research paper A(202)')
# Out:
# Overwriting 2_layout_basics.py

# %% [markdown]
# # 2. Input widgets & Interactivity
# **> Text inputs :**

# %%
# %%writefile 3_text_inputs.py
import streamlit as st

st.title('Text input Demo')

name=st.text_input("Enter your name")
comments=st.text_area("Any comments or feedback ? ")

st.write('Live output')

if name:
    st.write("Hello , **{name}**👍 ")
if comments:
    st.write('**Your Comments :**')
    st.write(comments)
# Out:
# Overwriting 3_text_inputs.py

# %%
# %%writefile 4_number_slider.py
import streamlit as st

st.title('Number Input & slider demo')

age=st.number_input("Enter your age : ",min_value=0,max_value=100,value=25)
rating=st.slider('rate this session (1-10)',min_value=1,max_value=10,value=5)

st.write(f'Your Age :{age}')
st.write(f"You rated this session :{rating}/10 ")
# Out:
# Overwriting 4_number_slider.py

# %%
# %%writefile 5_selection_widge.py
import streamlit as st
st.title("Selection widget Demo")

course=st.selectbox("Select course :",['python','FSD','DE','PS'])
prefered_days=st.multiselect('prefered Days for Extra Lectures',
                            ['monday','tuesday','wednesday','thursday','friday','saturday'])
delivery_mode=st.radio('Prefered  Delivery Mode',['offline','online','hybrid'])

subscribe=st.checkbox("Subscribe to course updates")
st.write("---")
st.write(f"**Course :** {course}")
st.write(f"**Preffered Days  :** {','.join(prefered_days)if prefered_days else none}")

st.write(f"**Dilevery mode :** {delivery_mode}")
st.write(f"**Subscribe :** {'Yes' if subscribe else 'NO'}")
# Out:
# Overwriting 5_selection_widge.py

# %%
# %%writefile 5_selection_widge.py
import streamlit as st
